# %%
# !conda install -c conda-forge bs4 --yes

# !pip install html5lib

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: html5lib in /srv/conda/envs/notebook/lib/python3.6/site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.6/site-packages (from html5lib) (0.5.1)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py37h8f50634_1000         346 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     certifi-2020.4.5.1         |   py37hc8dfbb8_0         151 KB  conda-forge
#     cffi-1.14.0                |   py37hd463f26_0         221 KB  conda-forge
#     chardet-3.0.4              |py37hc8dfbb8_1006         169 KB  conda-forge
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     conda-package-handling-1.6.0|   py37h8f50634_2         945 KB  conda-forge
#     cryptography-2.9.2         |   py37hb09aad4_0         622 KB  conda-forge
#     idna-2.9                   |             py_1          52 KB  conda-forge
#     ld_impl_linux-64-2.34      |       h53a641e_0         616 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1007          47 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     pycosat-0.6.3              |py37h8f50634_1004         107 KB  conda-forge
#     pycparser-2.20             |             py_0          89 KB  conda-forge
#     pyopenssl-19.1.0           |             py_1          47 KB  conda-forge
#     pysocks-1.7.1              |   py37hc8dfbb8_1          27 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     requests-2.23.0            |     pyh8c360ce_2          47 KB  conda-forge
#     ruamel_yaml-0.15.80        |py37h8f50634_1001         267 KB  conda-forge
#     setuptools-46.1.3          |   py37hc8dfbb8_0         634 KB  conda-forge
#     six-1.14.0                 |             py_1          13 KB  conda-forge
#     tqdm-4.46.0                |     pyh9f0ad1d_0          50 KB  conda-forge
#     urllib3-1.25.9             |             py_0          92 KB  conda-forge
#     xz-5.2.5                   |       h516909a_0         430 KB  conda-forge
#     yaml-0.2.4                 |       h516909a_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py37h8f50634_1000
#   python_abi         conda-forge/linux-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2019.11.28-hecc5488_0 --> 2020.4.5.1-hecc5488_0
#   certifi                                 2019.11.28-py37_0 --> 2020.4.5.1-py37hc8dfbb8_0
#   cffi                                1.13.2-py37h8022711_0 --> 1.14.0-py37hd463f26_0
#   chardet                                   3.0.4-py37_1003 --> 3.0.4-py37hc8dfbb8_1006
#   conda                                        4.8.2-py37_0 --> 4.8.3-py37hc8dfbb8_1
#   conda-package-han~                   1.6.0-py37h516909a_1 --> 1.6.0-py37h8f50634_2
#   cryptography                           2.8-py37h72c5cf5_1 --> 2.9.2-py37hb09aad4_0
#   idna               conda-forge/linux-64::idna-2.8-py37_1~ --> conda-forge/noarch::idna-2.9-py_1
#   ld_impl_linux-64                        2.33.1-h53a641e_8 --> 2.34-h53a641e_0
#   libffi                                3.2.1-he1b5a44_1006 --> 3.2.1-he1b5a44_1007
#   openssl                                 1.1.1d-h516909a_0 --> 1.1.1g-h516909a_0
#   pycosat                           0.6.3-py37h516909a_1002 --> 0.6.3-py37h8f50634_1004
#   pycparser          conda-forge/linux-64::pycparser-2.19-~ --> conda-forge/noarch::pycparser-2.20-py_0
#   pyopenssl          conda-forge/linux-64::pyopenssl-19.1.~ --> conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pysocks                                      1.7.1-py37_0 --> 1.7.1-py37hc8dfbb8_1
#   requests           conda-forge/linux-64::requests-2.22.0~ --> conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   ruamel_yaml                     0.15.80-py37h516909a_1000 --> 0.15.80-py37h8f50634_1001
#   setuptools                                  45.2.0-py37_0 --> 46.1.3-py37hc8dfbb8_0
#   six                conda-forge/linux-64::six-1.14.0-py37~ --> conda-forge/noarch::six-1.14.0-py_1
#   tqdm                                          4.42.1-py_0 --> 4.46.0-pyh9f0ad1d_0
#   urllib3            conda-forge/linux-64::urllib3-1.25.7-~ --> conda-forge/noarch::urllib3-1.25.9-py_0
#   xz                                    5.2.4-h14c3975_1001 --> 5.2.5-h516909a_0
#   yaml                                     0.2.2-h516909a_1 --> 0.2.4-h516909a_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
#get html from wiki page and create soup object
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(source.text, 'lxml')

# %%
#using soup object, iterate the .wikitable to get the data from the HTML page and store it into a list
data = []
columns = []
table = soup.find(class_='wikitable')
for index, tr in enumerate(table.find_all('tr')):
    section = []
    for td in tr.find_all(['th','td']):
        section.append(td.text.rstrip())
    
    #First row of data is the header
    if (index == 0):
        columns = section
    else:
        data.append(section)

#convert list into Pandas DataFrame
canada_df = pd.DataFrame(data = data,columns = columns)
canada_df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
#Remove Boroughs that are 'Not assigned'
canada_df = canada_df[canada_df['Borough'] != 'Not assigned']
canada_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
canada_df.shape
# Out:
# (103, 3)
